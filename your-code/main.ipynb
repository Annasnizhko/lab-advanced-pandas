# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
admissions_predict = pd.read_csv('./data/Admission_Predict.csv')
admissions_predict
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
admissions_predict.columns = admissions_predict.columns.str.strip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
admissions_predict.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
missing_data = admissions_predict.isnull().sum()
missing_data
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
admissions_predict.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
admissions_predict.set_index('Serial No.', inplace=True)

# %%
admissions_predict.head(10)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
# 6                 321          109                  3  3.0  4.0  8.20
# 7                 308          101                  2  3.0  4.0  7.90
# 8                 302          102                  1  2.0  1.5  8.00
# 9                 323          108                  3  3.5  3.0  8.60
# 10                327          111                  4  4.0  4.5  9.00
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
admissions_predict['GRE Score'].unique()
# Out:
# array([337, 316, 322, 314, 330, 321, 308, 302, 323, 327, 328, 307, 311,
#        317, 319, 318, 303, 325, 334, 336, 298, 295, 310, 300, 338, 340,
#        331, 320, 299, 304, 313, 332, 326, 329, 339, 312, 324, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293])

# %%
len(admissions_predict['CGPA'].unique())
# Out:
# 168

# %%
# your code here
duplicate_rows = admissions_predict[admissions_predict.duplicated(subset=['GRE Score', 'CGPA'], keep=False)]

duplicate_rows
# Out:
# Empty DataFrame
# Columns: [GRE Score, TOEFL Score, University Rating, SOP, LOR, CGPA, Research, Chance of Admit]
# Index: []

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here
admissions_predict.reset_index(inplace=True)

# %%
admissions_predict.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
admissions_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         385 non-null    int64
#  1   GRE Score          385 non-null    int64
#  2   TOEFL Score        385 non-null    int64
#  3   University Rating  385 non-null    int64
#  4   SOP                385 non-null    float64
#  5   LOR                385 non-null    float64
#  6   CGPA               385 non-null    float64
#  7   Research           385 non-null    int64
#  8   Chance of Admit    385 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 27.2 KB

# %%
# your code here
filtered_df = admissions_predict[(admissions_predict['CGPA'] > 9) & (admissions_predict['Research'] == 1)]
filtered_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 4             5        330          115                  5  4.5  3.0  9.34
# 10           11        328          112                  4  4.0  4.5  9.10
# 19           20        328          116                  5  5.0  5.0  9.50
# 20           21        334          119                  5  5.0  4.5  9.70
# ..          ...        ...          ...                ...  ...  ...   ...
# 379         380        329          111                  4  4.5  4.0  9.23
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
filtered_df2 = admissions_predict[(admissions_predict['CGPA'] > 9) & (admissions_predict['SOP'] < 3.5)]
filtered_df2
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 28           29        338          118                  4  3.0  4.5  9.40
# 62           63        327          114                  3  3.0  3.0  9.02
# 140         141        326          114                  3  3.0  3.0  9.11
# 217         218        324          111                  4  3.0  3.0  9.01
# 381         382        325          107                  3  3.0  3.5  9.11
#
#      Research  Chance of Admit
# 28          1             0.91
# 62          0             0.61
# 140         1             0.83
# 217         1             0.82
# 381         1             0.84

# %%
mean_chance_of_admit = filtered_df2['Chance of Admit'].mean()
mean_chance_of_admit
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    # your code here
    col_mean = np.mean(col)
    col_std = np.std(col)
    stand_col = (col - col_mean)/col_std
    return stand_col

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here
admissions_predict['CGPA_std'] = standardize(admissions_predict['CGPA'])

# %%
admissions_predict['LOR_std'] = standardize(admissions_predict['LOR'])

# %%
admissions_predict['GRE_std'] = standardize(admissions_predict['GRE Score'])

# %%
admissions_predict.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   LOR_std   GRE_std
# 0         1             0.92  1.750174  1.193197  1.755663
# 1         1             0.72 -0.992501  0.076840 -0.063450
# 2         1             0.80  0.121191 -1.039517  0.456297
# 3         0             0.65 -0.643433 -0.481338 -0.236698
# 4         1             0.90  1.234884 -0.481338  1.149292

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions_predict.shape[0])

# %%
decision_choice
# Out:
# ['LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
admissions_predict.loc[0, 'CGPA_std']
# Out:
# 1.7501740733332034

# %%
# your code here
decision_values = []
idx = 0
for c in decision_choice:
    decision_values.append(admissions_predict.loc[idx, c])
    idx += 1

# %%
admissions_predict['deciding_column'] = decision_values
admissions_predict
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
def judge(v):
    if v > 0.8:
        return 1
    else:
        return 0
    
admissions_predict['decision'] = admissions_predict['deciding_column'].apply(judge)
admissions_predict
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here
admissions_predict['decision'].sum()
# Out:
# 85

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here
admissions_predict.columns = admissions_predict.columns.str.replace(' ', '_').str.lower().str.replace('.', '')
# Out:
# /var/folders/fd/4q7kwxtj3_z50glmb8_db97m0000gp/T/ipykernel_89060/1077544689.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   admissions_predict.columns = admissions_predict.columns.str.replace(' ', '_').str.lower().str.replace('.', '')

# %%
admissions_predict
# Out:
#      serial_no  gre_score  toefl_score  university_rating  sop  lor  cgpa  \
# 0            1        337          118                  4  4.5  4.5  9.65
# 1            2        316          104                  3  3.0  3.5  8.00
# 2            3        322          110                  3  3.5  2.5  8.67
# 3            4        314          103                  2  2.0  3.0  8.21
# 4            5        330          115                  5  4.5  3.0  9.34
# ..         ...        ...          ...                ...  ...  ...   ...
# 380        381        324          110                  3  3.5  3.5  9.04
# 381        382        325          107                  3  3.0  3.5  9.11
# 382        383        330          116                  4  5.0  4.5  9.45
# 383        384        312          103                  3  3.5  4.0  8.78
# 384        385        333          117                  4  5.0  4.0  9.66
#
#      research  chance_of_admit  cgpa_std   lor_std   gre_std  deciding_column  \
# ...

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
admissions_predict.loc[admissions_predict['university_rating'] >= 4, 'gre_score'] += 10

# %%
admissions_predict
# Out:
#      serial_no  gre_score  toefl_score  university_rating  sop  lor  cgpa  \
# 0            1        347          118                  4  4.5  4.5  9.65
# 1            2        316          104                  3  3.0  3.5  8.00
# 2            3        322          110                  3  3.5  2.5  8.67
# 3            4        314          103                  2  2.0  3.0  8.21
# 4            5        340          115                  5  4.5  3.0  9.34
# ..         ...        ...          ...                ...  ...  ...   ...
# 380        381        324          110                  3  3.5  3.5  9.04
# 381        382        325          107                  3  3.0  3.5  9.11
# 382        383        340          116                  4  5.0  4.5  9.45
# 383        384        312          103                  3  3.5  4.0  8.78
# 384        385        343          117                  4  5.0  4.0  9.66
#
#      research  chance_of_admit  cgpa_std   lor_std   gre_std  deciding_column  \
# ...

# %%
admissions_predict['gre_score']
# Out:
# 0      347
# 1      316
# 2      322
# 3      314
# 4      340
#       ...
# 380    324
# 381    325
# 382    340
# 383    312
# 384    343
# Name: gre_score, Length: 385, dtype: int64

# %%
adjusted_gre = pd.cut(admissions_predict['gre_score'], 4)

# %%
adjusted_gre
# Out:
# 0      (335.0, 350.0]
# 1      (305.0, 320.0]
# 2      (320.0, 335.0]
# 3      (305.0, 320.0]
# 4      (335.0, 350.0]
#             ...
# 380    (320.0, 335.0]
# 381    (320.0, 335.0]
# 382    (335.0, 350.0]
# 383    (305.0, 320.0]
# 384    (335.0, 350.0]
# Name: gre_score, Length: 385, dtype: category
# Categories (4, interval[float64, right]): [(289.94, 305.0] < (305.0, 320.0] < (320.0, 335.0] < (335.0, 350.0]]
